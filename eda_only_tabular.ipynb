# %%
import pandas as pd

# %%
import sys
sys.path.append('../')  
from utils import eda_helper

# %%
df=pd.read_csv('../data/train_part1_cleaned.csv')

# %%
df
# Out:
#              date   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      2015-05-05  268643         4       2.25         1810      9240     2.0
# 1      2014-07-08  245000         3       2.50         1600      2788     2.0
# 2      2015-01-15  200000         4       2.50         1720      8638     2.0
# 3      2015-04-27  352499         2       2.25         1240       705     2.0
# 4      2014-12-05  232000         3       2.00         1280     13356     1.0
# ...           ...     ...       ...        ...          ...       ...     ...
# 16204  2014-11-13  378000         3       1.50         1000      6914     1.0
# 16205  2014-11-11  399950         3       2.50         3087      5002     2.0
# 16206  2014-09-30  575000         3       2.50         2120      4780     2.0
# 16207  2014-06-20  245000         1       0.75          380     15000     1.0
# 16208  2015-03-25  315000         4       2.50         3130      5999     2.0
#
# ...

# %% [markdown]
# # Univariate analysis

# %%
df['bedrooms'].value_counts()
# Out:
# bedrooms
# 3     7380
# 4     5128
# 2     2098
# 5     1213
# 6      197
# 1      142
# 7       26
# 8        9
# 0        8
# 9        5
# 10       2
# 33       1
# Name: count, dtype: int64

# %%
df[df['bedrooms']>7]
# Out:
#              date    price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 2803   2015-03-17  1400000         9       4.00         4620      5508
# 3015   2014-10-07  2150000         8       6.00         4340      9415
# 3042   2015-03-13   934000         9       3.00         2820      4480
# 3193   2014-06-25   640000        33       1.75         1620      6000
# 3220   2014-05-07   599999         9       4.50         3830      6988
# 3609   2014-07-03   340000         8       2.75         2790      6695
# 4030   2014-10-16   900000         8       4.00         4020      7500
# 5202   2014-12-04   490000         8       5.00         2800      2580
# 5296   2014-05-28  1970000         8       3.50         4440      6480
# 5777   2014-08-14  1148000        10       5.25         4590     10920
# 8733   2015-02-19   373000         8       3.00         2850     12714
# 8752   2015-01-06   700000         9       3.00         3680      4400
# ...

# %%
df[df['zipcode']==98103]['price'].max()
# Out:
# 1695000

# %%
eda_helper.num_univar_plots(df,'bedrooms')
# Out:
# <h2>Univariate Analysis of bedrooms</h2>
# <h3></h3>

# %%
eda_helper.num_summary(df,'bedrooms')
# Out:
# <h2>bedrooms</h2>
# <h3>Quick Glance:</h3>
# 0        4
# 1        3
# 2        4
# 3        2
# 4        3
#         ..
# 16204    3
# 16205    3
# 16206    3
# 16207    1
# 16208    4
# Name: bedrooms, Length: 16209, dtype: int64
# <h3>Meta-data:</h3>
# Data Type      : int64
# Missing Data   : 0 rows (0.00 %)
# Available Data : 16,209 / 16,209 rows
# <h3>Percentiles:</h3>
#             value
# percentile
# 0             0.0
# 5             2.0
# 10            2.0
# 25            3.0
# 50            3.0
# 75            4.0
# 90            4.0
# 95            5.0
# 99            6.0
# 100          33.0
# <h3>Central Tendancy:</h3>
#                        value
# mean                3.367820
# trimmed mean (5%)   3.341079
# trimmed mean (10%)  3.334104
# median              3.000000
# <h3>Measure of Spread:</h3>
#                   value
# var            0.870993
# std            0.933270
# IQR            1.000000
# mad            1.000000
# coef_variance  0.277114
# ...

# %% [markdown]
# # Bathrooms

# %%
eda_helper.num_summary(df,'bathrooms')
# Out:
# <h2>bathrooms</h2>
# <h3>Quick Glance:</h3>
# 0        2.25
# 1        2.50
# 2        2.50
# 3        2.25
# 4        2.00
#          ...
# 16204    1.50
# 16205    2.50
# 16206    2.50
# 16207    0.75
# 16208    2.50
# Name: bathrooms, Length: 16209, dtype: float64
# <h3>Meta-data:</h3>
# Data Type      : float64
# Missing Data   : 0 rows (0.00 %)
# Available Data : 16,209 / 16,209 rows
# <h3>Percentiles:</h3>
#             value
# percentile
# 0            0.00
# 5            1.00
# 10           1.00
# 25           1.50
# 50           2.25
# 75           2.50
# 90           3.00
# 95           3.50
# 99           4.25
# 100          8.00
# <h3>Central Tendancy:</h3>
#                        value
# mean                2.113054
# trimmed mean (5%)   2.078398
# trimmed mean (10%)  2.074254
# median              2.250000
# <h3>Measure of Spread:</h3>
#                   value
# var            0.585595
# std            0.765242
# IQR            1.000000
# mad            0.500000
# ...

# %%
eda_helper.num_univar_plots(df,'bathrooms')
# Out:
# <h2>Univariate Analysis of bathrooms</h2>
# <h3></h3>

# %%
df[df['bathrooms']==8]
# Out:
#             date    price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 4962  2014-10-13  7700000         6        8.0        12050     27600     2.5
#
#       waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 4962           0     3          4     13        8570           3480      1910
#
#       yr_renovated  zipcode  sqft_living15  sqft_lot15  year  month
# 4962          1987    98102           3940        8800  2014     10

# %%
# show me those datapoint with both bathrooms and bedrooms =0
df[(df['bathrooms']==0) & (df['bedrooms']==0)]
# Out:
#              date    price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 20     2015-02-05   380000         0        0.0         1470       979
# 3882   2014-06-24  1295650         0        0.0         4810     28008
# 4663   2014-09-26   142000         0        0.0          290     20875
# 16199  2015-04-13   139950         0        0.0          844      4269
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 20        3.0           0     2          3      8        1470              0
# 3882      2.0           0     0          3     12        4810              0
# 4663      1.0           0     0          1      1         290              0
# 16199     1.0           0     0          4      7         844              0
#
#        yr_built  yr_renovated  zipcode  sqft_living15  sqft_lot15  year  month
# 20         2006             0    98133           1470        1399  2015      2
# ...

# %%
df[df['bathrooms']==0]
# Out:
#              date    price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 20     2015-02-05   380000         0        0.0         1470       979
# 3656   2015-02-17    75000         1        0.0          670     43377
# 3882   2014-06-24  1295650         0        0.0         4810     28008
# 4663   2014-09-26   142000         0        0.0          290     20875
# 7578   2014-09-18   484000         1        0.0          690     23244
# 13005  2014-11-04   280000         1        0.0          600     24501
# 16199  2015-04-13   139950         0        0.0          844      4269
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 20        3.0           0     2          3      8        1470              0
# 3656      1.0           0     0          3      3         670              0
# 3882      2.0           0     0          3     12        4810              0
# 4663      1.0           0     0          1      1         290              0
# ...

# %% [markdown]
# # Sqft_living

# %%
eda_helper.num_univar_plots(df,'sqft_living')
# Out:
# <h2>Univariate Analysis of sqft_living</h2>
# <h3></h3>

# %%
eda_helper.num_summary(df,'sqft_living')
# Out:
# <h2>sqft_living</h2>
# <h3>Quick Glance:</h3>
# 0        1810
# 1        1600
# 2        1720
# 3        1240
# 4        1280
#          ...
# 16204    1000
# 16205    3087
# 16206    2120
# 16207     380
# 16208    3130
# Name: sqft_living, Length: 16209, dtype: int64
# <h3>Meta-data:</h3>
# Data Type      : int64
# Missing Data   : 0 rows (0.00 %)
# Available Data : 16,209 / 16,209 rows
# <h3>Percentiles:</h3>
#               value
# percentile
# 0             290.0
# 5             940.0
# 10           1090.0
# 25           1430.0
# 50           1910.0
# 75           2550.0
# 90           3240.0
# 95           3740.0
# 99           4920.0
# 100         12050.0
# <h3>Central Tendancy:</h3>
#                           value
# mean                2073.274601
# trimmed mean (5%)   2009.136678
# trimmed mean (10%)  1980.119747
# median              1910.000000
# <h3>Measure of Spread:</h3>
#                        value
# var            822666.217100
# std               907.009491
# ...

# %% [markdown]
# # sqft_lot

# %%
eda_helper.num_summary(df,'sqft_lot')
# Out:
# <h2>sqft_lot</h2>
# <h3>Quick Glance:</h3>
# 0         9240
# 1         2788
# 2         8638
# 3          705
# 4        13356
#          ...
# 16204     6914
# 16205     5002
# 16206     4780
# 16207    15000
# 16208     5999
# Name: sqft_lot, Length: 16209, dtype: int64
# <h3>Meta-data:</h3>
# Data Type      : int64
# Missing Data   : 0 rows (0.00 %)
# Available Data : 16,209 / 16,209 rows
# <h3>Percentiles:</h3>
#                 value
# percentile
# 0               520.0
# 5              1755.0
# 10             3270.2
# 25             5004.0
# 50             7599.0
# 75            10631.0
# 90            21324.0
# 95            43010.2
# 99           213008.0
# 100         1164794.0
# <h3>Central Tendancy:</h3>
#                            value
# mean                14867.673145
# trimmed mean (5%)    9185.671191
# trimmed mean (10%)   8214.868841
# median               7599.000000
# <h3>Measure of Spread:</h3>
#                       value
# var            1.507435e+09
# ...

# %%
eda_helper.num_univar_plots(df,'sqft_lot')
# Out:
# <h2>Univariate Analysis of sqft_lot</h2>
# <h3></h3>

# %% [markdown]
# # Floors

# %%
df['floors'].value_counts()
# Out:
# floors
# 1.0    7970
# 2.0    6215
# 1.5    1414
# 3.0     489
# 2.5     117
# 3.5       4
# Name: count, dtype: int64

# %% [markdown]
# # waterfront

# %%
df['waterfront'].value_counts()
# Out:
# waterfront
# 0    16096
# 1      113
# Name: count, dtype: int64

# %%
df[df['waterfront']==1]['price'].mean()
# Out:
# 1591937.982300885

# %%
df[df['waterfront']==0]['price'].mean()
# Out:
# 530067.5211853876

# %% [markdown]
# # View

# %%
df['view'].value_counts()
# Out:
# view
# 0    14604
# 2      743
# 3      375
# 1      254
# 4      233
# Name: count, dtype: int64

# %%
df
# Out:
#              date   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      2015-05-05  268643         4       2.25         1810      9240     2.0
# 1      2014-07-08  245000         3       2.50         1600      2788     2.0
# 2      2015-01-15  200000         4       2.50         1720      8638     2.0
# 3      2015-04-27  352499         2       2.25         1240       705     2.0
# 4      2014-12-05  232000         3       2.00         1280     13356     1.0
# ...           ...     ...       ...        ...          ...       ...     ...
# 16204  2014-11-13  378000         3       1.50         1000      6914     1.0
# 16205  2014-11-11  399950         3       2.50         3087      5002     2.0
# 16206  2014-09-30  575000         3       2.50         2120      4780     2.0
# 16207  2014-06-20  245000         1       0.75          380     15000     1.0
# 16208  2015-03-25  315000         4       2.50         3130      5999     2.0
#
# ...

# %% [markdown]
# # Condition

# %%
df['condition'].value_counts()
# Out:
# condition
# 3    10538
# 4     4238
# 5     1277
# 2      131
# 1       25
# Name: count, dtype: int64

# %% [markdown]
# # Grade

# %%
df['grade'].value_counts()
# Out:
# grade
# 7     6761
# 8     4563
# 9     1943
# 6     1511
# 10     861
# 11     286
# 5      183
# 12      63
# 4       24
# 13      10
# 3        3
# 1        1
# Name: count, dtype: int64

# %% [markdown]
# # Year Built

# %%
df['yr_built'].value_counts()
# Out:
# yr_built
# 2014    415
# 2006    347
# 2005    346
# 2004    330
# 2007    323
#        ...
# 1933     23
# 1902     21
# 1935     18
# 1901     17
# 1934     14
# Name: count, Length: 116, dtype: int64

# %%
eda_helper.num_univar_plots(df,'yr_built')
# Out:
# <h2>Univariate Analysis of yr_built</h2>
# <h3></h3>

# %% [markdown]
# # yr_renovated

# %%
df['yr_renovated'].value_counts()
# Out:
# yr_renovated
# 0       15537
# 2014       68
# 2005       31
# 2003       27
# 2000       27
#         ...
# 1944        1
# 1945        1
# 1955        1
# 1946        1
# 1956        1
# Name: count, Length: 69, dtype: int64

# %%
# Convert zipcode to categorical variable

df['zipcode']=df['zipcode'].astype('str')
df['zipcode'].dtype
# Out:
# dtype('O')

# %%
df['zipcode']
# Out:
# 0        98055
# 1        98031
# 2        98003
# 3        98027
# 4        98042
#          ...
# 16204    98125
# 16205    98023
# 16206    98053
# 16207    98168
# 16208    98042
# Name: zipcode, Length: 16209, dtype: object

# %% [markdown]
# # Bi-variate analysis

# %%
eda_helper.correlation_heatmap(df,(20,10))

# %%
eda_helper.num_bivar_plots(df,'price','sqft_living')
# Out:
# <h2>Bi-variate Analysis between price and sqft_living</h2>
# <h3></h3>

# %%
eda_helper.num_bivar_plots(df,'price','bedrooms')
# Out:
# <h2>Bi-variate Analysis between price and bedrooms</h2>
# <h3></h3>

# %%
eda_helper.num_bivar_plots(df,'price','bathrooms')
# Out:
# <h2>Bi-variate Analysis between price and bathrooms</h2>
# <h3></h3>

# %%
eda_helper.num_cat_bivar_plots(df,'price','zipcode',figsize=(20,10))
# Out:
# <h2>Bi-variate Analysis between zipcode and price</h2>
# <h3></h3>

# %%
eda_helper.num_cat_bivar_plots(df,'price','floors',figsize=(20,10))
# Out:
# <h2>Bi-variate Analysis between floors and price</h2>
# <h3></h3>

# %%
eda_helper.num_cat_bivar_plots(df,'price','waterfront',figsize=(20,10))
# Out:
# <h2>Bi-variate Analysis between waterfront and price</h2>
# <h3></h3>

# %%
df
# Out:
#              date   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      2015-05-05  268643         4       2.25         1810      9240     2.0
# 1      2014-07-08  245000         3       2.50         1600      2788     2.0
# 2      2015-01-15  200000         4       2.50         1720      8638     2.0
# 3      2015-04-27  352499         2       2.25         1240       705     2.0
# 4      2014-12-05  232000         3       2.00         1280     13356     1.0
# ...           ...     ...       ...        ...          ...       ...     ...
# 16204  2014-11-13  378000         3       1.50         1000      6914     1.0
# 16205  2014-11-11  399950         3       2.50         3087      5002     2.0
# 16206  2014-09-30  575000         3       2.50         2120      4780     2.0
# 16207  2014-06-20  245000         1       0.75          380     15000     1.0
# 16208  2015-03-25  315000         4       2.50         3130      5999     2.0
#
# ...

# %%
eda_helper.num_cat_bivar_plots(df,'price','view')
# Out:
# <h2>Bi-variate Analysis between view and price</h2>
# <h3></h3>

# %%
eda_helper.num_cat_bivar_plots(df,'price','condition')
# Out:
# <h2>Bi-variate Analysis between condition and price</h2>
# <h3></h3>

# %%
eda_helper.num_cat_bivar_plots(df,'price','grade')
# Out:
# <h2>Bi-variate Analysis between grade and price</h2>
# <h3></h3>

# %% [markdown]
# # Derived features

# %%
# first create time since built which is difference between year and yr_built   
df['time_since_built']=df['year']-df['yr_built']

# %%
df
# Out:
#              date   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      2015-05-05  268643         4       2.25         1810      9240     2.0
# 1      2014-07-08  245000         3       2.50         1600      2788     2.0
# 2      2015-01-15  200000         4       2.50         1720      8638     2.0
# 3      2015-04-27  352499         2       2.25         1240       705     2.0
# 4      2014-12-05  232000         3       2.00         1280     13356     1.0
# ...           ...     ...       ...        ...          ...       ...     ...
# 16204  2014-11-13  378000         3       1.50         1000      6914     1.0
# 16205  2014-11-11  399950         3       2.50         3087      5002     2.0
# 16206  2014-09-30  575000         3       2.50         2120      4780     2.0
# 16207  2014-06-20  245000         1       0.75          380     15000     1.0
# 16208  2015-03-25  315000         4       2.50         3130      5999     2.0
#
# ...

# %%
df.loc[df['yr_renovated'] == 0, 'yr_renovated'] = df['yr_built']

# %%
df
# Out:
#              date   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      2015-05-05  268643         4       2.25         1810      9240     2.0
# 1      2014-07-08  245000         3       2.50         1600      2788     2.0
# 2      2015-01-15  200000         4       2.50         1720      8638     2.0
# 3      2015-04-27  352499         2       2.25         1240       705     2.0
# 4      2014-12-05  232000         3       2.00         1280     13356     1.0
# ...           ...     ...       ...        ...          ...       ...     ...
# 16204  2014-11-13  378000         3       1.50         1000      6914     1.0
# 16205  2014-11-11  399950         3       2.50         3087      5002     2.0
# 16206  2014-09-30  575000         3       2.50         2120      4780     2.0
# 16207  2014-06-20  245000         1       0.75          380     15000     1.0
# 16208  2015-03-25  315000         4       2.50         3130      5999     2.0
#
# ...

# %%
df['time_since_renovated']=df['year']-df['yr_renovated']

# %%
df
# Out:
#              date   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      2015-05-05  268643         4       2.25         1810      9240     2.0
# 1      2014-07-08  245000         3       2.50         1600      2788     2.0
# 2      2015-01-15  200000         4       2.50         1720      8638     2.0
# 3      2015-04-27  352499         2       2.25         1240       705     2.0
# 4      2014-12-05  232000         3       2.00         1280     13356     1.0
# ...           ...     ...       ...        ...          ...       ...     ...
# 16204  2014-11-13  378000         3       1.50         1000      6914     1.0
# 16205  2014-11-11  399950         3       2.50         3087      5002     2.0
# 16206  2014-09-30  575000         3       2.50         2120      4780     2.0
# 16207  2014-06-20  245000         1       0.75          380     15000     1.0
# 16208  2015-03-25  315000         4       2.50         3130      5999     2.0
#
# ...

# %%
eda_helper.num_bivar_plots(df,'time_since_built','price')
# Out:
# <h2>Bi-variate Analysis between time_since_built and price</h2>
# <h3></h3>

# %%
eda_helper.correlation_heatmap(df,(30,20))
